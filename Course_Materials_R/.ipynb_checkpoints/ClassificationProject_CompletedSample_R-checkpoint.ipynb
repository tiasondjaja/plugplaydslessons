# %% [markdown]
# # Classification Project
#
# ## Overview
#
# You will be analyzing a movie data. Your goals in this project are
# + to build classifiers that predict the genre of a movie--action or romance--based on the frequencies in which certain words appear in the movie script and
# + to analyze the performance of these classifiers.
#
# Project components:
# 1. **Data exploration and feature selection**
#
#     In order to get a sense of what features can help us distinguish an action movie from a romance movie, you would have to do some initial exploration and visualization of your training dataset.  Your project should include at least three data visualizations that help justify how you design your classifier.<br><br>
#
# 2. **Development of your own classifier**
#
#     Your task here is to build your own "simple classifier"; it should use at least three features and you should use at least two if-else statements.  This classifier should be informed by your initial data exploration (step 1 above).<br><br>
#
# 3. **Assessment of your classifier**
#
#     Assess how your classifier does in predicting the genres of the movies in your test dataset.  You should measure the accuracy of your classifier.  Then, you should use one other metric (this could be one of the metrics we have discussed in class or one that you construct yourself).  If you use a metric that you created yourself, please include a brief explanation of your idea.<br><br>
#
# 4. **Comparison of the performance of your classifier to that of a k-Nearest Neighbor Classifier**
#
#     Use a kNN classifier with a particular choice of $k$ to predict the genre of the movies in your test dataset and assess the quality of the predictions.  Explain your choice of $k$.  Compare the performance of your classifier to that of the kNN classifier; comment on the result.<br><br>
#
# 5. **Writeup (Summary and Conclusion)**
#
#     Your writeup should include
#
#     + An explanation of your data visualizations (why you picked the pairs of words to plot, etc.) and an interpretation of your data visualization
#     + An explanation of your simple classifier, including how the data visualizations you produced inform the simple classifier(s) you constructed
#     + A discussion on the metrics you use to assess the performance of the classifiers
#     + A discussion of the performance of your simple classifier(s), in terms of accuracy and one other metric
#     + A discussion of the performance of the kNN classifier, including what $k$ value you chose and why, in terms of accuracy and one other metric
#     + A summary of how the simple classifier(s) you constructed compares to the kNN classifier, which classifier you would recommend to use, the shortcomings of your chosen classifiers, and any ideas for future improvements

# %% [markdown]
# ## Team Information
#
# Team members: (enter your names here)
#
# NetIDs:

# %% [markdown]
# ## 0. Load data and libraries; split data into training and test data

# %%
# libraries
library('ggplot2')
library('dplyr')
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 3.5.2"Warning message:
# "package 'dplyr' was built under R version 3.5.2"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
# load data
moviesdata <- read.csv('../datasets/movies.csv')

# %%
# size of data
dim(moviesdata) # 242 rows, 5006 columns -> 242 movies, 5006 columns
# Out:
# [1]  242 5006

# %%
# Decide how many rows will be used for training and testing (the sum should be 242)
num_train <- 169
num_test <- 73

# Split moviesdata into two
#    scramble rows of the movies data
set.seed(1)
rows_scrambled <- sample( 1:242, 242, replace=FALSE )
moviesdata_scrambled <- moviesdata[rows_scrambled,]

#    split
training_rows_indices <- 1:num_train
test_rows_indices <- (num_train+1):242

training_data <- moviesdata_scrambled[training_rows_indices, ]
test_data <- moviesdata_scrambled[test_rows_indices, ]

# %% [markdown]
# ## 1. Data exploration and feature selection

# %%
# peek into the dataset
head(training_data, 4)
# Out:
#     Title                    Genre   Year Rating X..Votes X..Words i
# 65  my best friend's wedding romance 1997 6.2    37682    3308     0.03506650
# 90  roughshod                action  1949 6.9      115    4767     0.03608139
# 138 the time machine         action  2002 5.7    32900    4751     0.03725531
# 218 cruel intentions         romance 1999 6.7    67532    5581     0.04694499
#     the        to         a          ... foster pub vegetarian garrison grammoo
# 65  0.03506650 0.02660218 0.02176542 ... 0      0   0          0        0
# 90  0.03041745 0.03356409 0.02496329 ... 0      0   0          0        0
# 138 0.03683435 0.02967796 0.02167965 ... 0      0   0          0        0
# 218 0.02257660 0.03153557 0.01988891 ... 0      0   0          0        0
#     chimney bikini richter psychopath fling
# 65  0       0      0       0          0
# 90  0       0      0       0          0
# 138 0       0      0       0          0
# 218 0       0      0       0          0

# %%
cols <- colnames(training_data)

print(cols)
# column 1 = Title
# column 2 = Genre <- LABEL
# column 3 = Year
# column 4 = Rating
# column 5 = X..Votes
# column 6 = X..Words
# columns 7 onwards = words <- VARIABLES
# Out:
#    [1] "Title"         "Genre"         "Year"          "Rating"
#    [5] "X..Votes"      "X..Words"      "i"             "the"
#    [9] "to"            "a"             "it"            "and"
#   [13] "that"          "of"            "your"          "what"
#   [17] "in."           "me"            "is"            "do"
#   [21] "thi"           "dont"          "he"            "for."
#   [25] "im"            "know"          "have"          "be"
#   [29] "my"            "we"            "not"           "on"
#   [33] "go"            "no"            "wa"            "but"
#   [37] "with"          "are"           "get"           "just"
#   [41] "like"          "all"           "there"         "about"
#   [45] "want"          "if."           "here"          "out"
#   [49] "well"          "think"         "they"          "up"
#   [53] "him"           "can"           "one"           "were"
#   [57] "how"           "got"           "she"           "at"
#   [61] "right"         "now"           "look"          "come"
#   [65] "her"           "see"           "whi"           "did"
#   [69] "oh"            "hi"            "who"           "say"
#   [73] "as"            "tell"          "time"          "good"
#   [77] "ill"           "ye"            "when"          "take"
#   [81] "yeah"          "from"          "where"         "an"
#   [85] "thing"         "let"           "cant"          "back"
#   [89] "make"          "them"          "some"          "been"
#   [93] "or"            "would"         "us"            "then"
#   [97] "could"         "didnt"         "man"           "way"
#  [101] "someth"        "had"           "mean"          "never"
#  [105] "ive"           "talk"          "too"           "okay"
#  [109] "need"          "sure"          "realli"        "down"
#  [113] "love"          "littl"         "more"          "work"
#  [117] "our"           "call"          "by"            "give"
#  [121] "mr"            "ani"           "onli"          "off"
#  [125] "gonna"         "mayb"          "veri"          "over"
#  [129] "tri"           "two"           "thank"         "peopl"
#  [133] "ha"            "much"          "year"          "day"
#  [137] "said"          "am"            "sorri"         "even"
#  [141] "should"        "happen"        "feel"          "find"
#  [145] "becaus"        "sir"           "thought"       "anyth"
#  [149] "into"          "id"            "other"         "theyr"
#  [153] "noth"          "life"          "ask"           "use"
#  [157] "befor"         "night"         "live"          "ever"
#  [161] "better"        "still"         "first"         "youv"
#  [165] "wait"          "help"          "keep"          "than"
#  [169] "last"          "put"           "these"         "must"
#  [173] "name"          "hey"           "around"        "long"
#  [177] "believ"        "those"         "alway"         "leav"
#  [181] "wont"          "place"         "pleas"         "their"
#  [185] "after"         "doe"           "told"          "friend"
#  [189] "youll"         "isnt"          "great"         "again"
#  [193] "away"          "everyth"       "stop"          "stay"
#  [197] "doesnt"        "old"           "money"         "lot"
#  [201] "care"          "start"         "wouldnt"       "kind"
#  [205] "big"           "new"           "bad"           "run"
#  [209] "rememb"        "listen"        "home"          "minut"
#  [213] "enough"        "might"         "guess"         "made"
#  [217] "nice"          "through"       "cours"         "wrong"
#  [221] "mind"          "world"         "everi"         "understand"
#  [225] "boy"           "miss"          "three"         "someon"
#  [229] "hear"          "left"          "uh"            "fine"
#  [233] "anoth"         "move"          "yourself"      "job"
#  [237] "own"           "real"          "father"        "els"
#  [241] "gotta"         "turn"          "car"           "show"
#  [245] "busi"          "done"          "suppos"        "play"
#  [249] "came"          "huh"           "head"          "hous"
#  [253] "wasnt"         "knew"          "idea"          "youd"
#  [257] "weve"          "which"         "best"          "mother"
#  [261] "marri"         "matter"        "hand"          "meet"
#  [265] "worri"         "saw"           "room"          "same"
#  [269] "pretti"        "havent"        "chang"         "em"
#  [273] "hour"          "aint"          "week"          "tonight"
#  [277] "seen"          "whole"         "seem"          "five"
#  [281] "mani"          "onc"           "tomorrow"      "watch"
#  [285] "walk"          "without"       "went"          "found"
#  [289] "ya"            "heard"         "woman"         "person"
#  [293] "next."         "problem"       "morn"          "most"
#  [297] "hundr"         "couldnt"       "deal"          "hold"
#  [301] "togeth"        "men"           "few"           "quit"
#  [305] "bring"         "yet"           "hello"         "differ"
#  [309] "while."        "alreadi"       "read"          "question"
#  [313] "myself"        "word"          "took"          "second"
#  [317] "wonder"        "end"           "forget"        "wife"
#  [321] "sit"           "ago"           "part"          "probabl"
#  [325] "figur"         "hard"          "caus"          "until"
#  [329] "pick"          "alon"          "stori"         "anyway"
#  [333] "drink"         "point"         "power"         "late"
#  [337] "brother"       "open"          "dad"           "exactli"
#  [341] "stuff"         "eye"           "sinc"          "four"
#  [345] "ten"           "hate"          "crazi"         "case"
#  [349] "hurt"          "such"          "sound"         "pay"
#  [353] "close"         "beauti"        "arent"         "face"
#  [357] "nobodi"        "stand"         "chanc"         "actual"
#  [361] "school"        "check"         "both"          "anyon"
#  [365] "save"          "interest"      "six"           "famili"
#  [369] "gone"          "captain"       "eat"           "mine"
#  [373] "sleep"         "plan"          "offic"         "doctor"
#  [377] "set"           "afraid"        "somebodi"      "thousand"
#  [381] "today"         "trust"         "wanna"         "hit"
#  [385] "drive"         "shut"          "month"         "readi"
#  [389] "happi"         "send"          "under"         "lost"
#  [393] "cut"           "shot"          "later"         "reason"
#  [397] "rest"          "whatev"        "theyll"        "side"
#  [401] "TRUE."         "easi"          "least"         "soon"
#  [405] "wish"          "break."        "anybodi"       "gave"
#  [409] "troubl"        "dollar"        "sometim"       "book"
#  [413] "town"          "door"          "order"         "far"
#  [417] "pull"          "each"          "learn"         "everybodi"
#  [421] "phone"         "coupl"         "anymor"        "game"
#  [425] "lose"          "possibl"       "heart"         "follow"
#  [429] "alright"       "half"          "promis"        "ladi"
#  [433] "ship"          "dr"            "answer"        "wed"
#  [437] "expect"        "line"          "speak"         "import"
#  [441] "buy"           "everyon"       "truth"         "met"
#  [445] "million"       "high"          "parti"         "write"
#  [449] "either"        "insid"         "women"         "honey"
#  [453] "citi"          "dream"         "report"        "funni"
#  [457] "along"         "light"         "excus"         "goe"
#  [461] "act"           "scare"         "war"           "wear"
#  [465] "street"        "sort"          "safe"          "bit"
#  [469] "against"       "though"        "mom"           "bed"
#  [473] "cop"           "dinner"        "hang"          "drop"
#  [477] "fall"          "fact"          "twenti"        "bet"
#  [481] "dog"           "polic"         "almost"        "aliv"
#  [485] "water"         "system"        "touch"         "fun"
#  [489] "human"         "train"         "ahead"         "itll"
#  [493] "shouldnt"      "tire"          "piec"          "blood"
#  [497] "between"       "perhap"        "ride"          "build"
#  [501] "date"          "husband"       "fli"           "bodi"
#  [505] "full"          "moment"        "king"          "compani"
#  [509] "countri"       "apart"         "behind"        "ah"
#  [513] "control"       "pictur"        "handl"         "front"
#  [517] "shall"         "state"         "finish"        "forc"
#  [521] "news"          "sens"          "free"          "pass"
#  [525] "sent"          "worth"         "seriou"        "sister"
#  [529] "danger"        "abl"           "plane"         "secret"
#  [533] "explain"       "hair"          "danc"          "record"
#  [537] "hot"           "command"       "surpris"       "werent"
#  [541] "luck"          "cold"          "also"          "becom"
#  [545] "fast"          "catch"         "bank"          "goodby"
#  [549] "letter"        "complet"       "clear"         "straight"
#  [553] "kiss"          "clean"         "theyv"         "daughter"
#  [557] "top"           "gener"         "himself"       "till"
#  [561] "land"          "begin"         "beat"          "choic"
#  [565] "dress"         "ok"            "decid"         "somewher"
#  [569] "sign"          "perfect"       "brought"       "outsid"
#  [573] "dark"          "cool"          "protect"       "hotel"
#  [577] "lucki"         "taken"         "aw"            "fool"
#  [581] "eight"         "mistak"        "count"         "paper"
#  [585] "glad"          "except"        "small"         "dear"
#  [589] "bother"        "besid"         "throw"         "win"
#  [593] "known"         "natur"         "fifti"         "cover"
#  [597] "stick"         "food"          "rather"        "coffe"
#  [601] "secur"         "earth"         "imagin"        "absolut"
#  [605] "sell"          "arm"           "past"          "special"
#  [609] "final"         "prison"        "honor"         "air"
#  [613] "lord"          "parent"        "lock"          "realiz"
#  [617] "unless"        "outta"         "mouth"         "feet"
#  [621] "presid"        "offer"         "less"          "lead"
#  [625] "poor"          "charg"         "hors"          "children"
#  [629] "red"           "seven"         "hide"          "daddi"
#  [633] "cmon"          "cannot"        "suit"          "step"
#  [637] "laugh"         "anim"          "inform"        "boat"
#  [641] "terribl"       "movi"          "felt"          "law"
#  [645] "return"        "smart"         "total"         "yesterday"
#  [649] "usual"         "shell"         "york"          "hed"
#  [653] "none"          "enjoy"         "cloth"         "certainli"
#  [657] "card"          "reach"         "trip"          "key"
#  [661] "spend"         "joke"          "comput"        "park"
#  [665] "planet"        "bird"          "rule"          "howd"
#  [669] "oper"          "servic"        "jump"          "respons"
#  [673] "notic"         "prove"         "goin"          "machin"
#  [677] "futur"         "respect"       "partner"       "floor"
#  [681] "window"        "thirti"        "truck"         "middl"
#  [685] "hurri"         "tough"         "admir"         "ring"
#  [689] "smell"         "road"          "tape"          "posit"
#  [693] "armi"          "agent"         "appreci"       "swear"
#  [697] "anywher"       "experi"        "favor"         "near"
#  [701] "mission"       "oclock"        "fair"          "breath"
#  [705] "buck"          "nine"          "nose"          "doin"
#  [709] "wors"          "relax"         "child"         "ought"
#  [713] "wast"          "welcom"        "file"          "fault"
#  [717] "join"          "age"           "smoke"         "bag"
#  [721] "glass"         "accid"         "team"          "major"
#  [725] "longer"        "fix"           "kinda"         "simpl"
#  [729] "rock"          "uncl"          "meant"         "darl"
#  [733] "creat"         "grow"          "involv"        "boss"
#  [737] "caught"        "radio"         "certain"       "pain"
#  [741] "bar"           "voic"          "practic"       "gold"
#  [745] "english"       "lieuten"       "strang"        "kick"
#  [749] "evil"          "whatd"         "entir"         "exist"
#  [753] "doubt"         "memori"        "fish"          "pari"
#  [757] "class"         "privat"        "tie"           "bastard"
#  [761] "public"        "tast"          "given"         "bout"
#  [765] "eh"            "station"       "guard"         "cost"
#  [769] "situat"        "messag"        "owe"           "teach"
#  [773] "knock"         "sake"          "space"         "belong"
#  [777] "impress"       "star"          "french"        "quiet"
#  [781] "nervou"        "prepar"        "box"           "wake"
#  [785] "instead"       "serv"          "tabl"          "account"
#  [789] "leg"           "agre"          "forgiv"        "ice"
#  [793] "doc"           "slow"          "present"       "track"
#  [797] "master"        "born"          "christma"      "round"
#  [801] "blue"          "consid"        "store"         "concern"
#  [805] "quick"         "rich"          "surviv"        "wall"
#  [809] "field"         "board"         "lunch"         "kept"
#  [813] "histori"       "normal"        "upset"         "jail"
#  [817] "excit"         "trick"         "hospit"        "theyd"
#  [821] "steal"         "broke"         "share"         "sing"
#  [825] "detect"        "mention"       "stone"         "arrest"
#  [829] "list"          "short"         "earli"         "forgot"
#  [833] "amaz"          "wyatt"         "neither"       "hasnt"
#  [837] "bought"        "allow"         "la"            "fill"
#  [841] "forev"         "colleg"        "maam"          "paid"
#  [845] "mess"          "pack"          "strong"        "ground"
#  [849] "risk"          "cross"         "nothin"        "disappear"
#  [853] "seat"          "across"        "ear"           "cri"
#  [857] "rais"          "madam"         "ran"           "suggest"
#  [861] "weird"         "travel"        "warn"          "whatr"
#  [865] "visit"         "shop"          "fellow"        "fit"
#  [869] "hire"          "peac"          "ruin"          "cash"
#  [873] "wrote"         "feed"          "invit"         "studi"
#  [877] "data"          "depend"        "wit"           "beg"
#  [881] "de"            "ii"            "fifteen"       "chief"
#  [885] "blame"         "hungri"        "direct"        "court"
#  [889] "yknow"         "marriag"       "push"          "twelv"
#  [893] "manag"         "beer"          "admit"         "pleasur"
#  [897] "treat"         "island"        "nut"           "type"
#  [901] "holi"          "music"         "bore"          "remind"
#  [905] "code"          "gentlemen"     "girlfriend"    "uhhuh"
#  [909] "club"          "lawyer"        "assum"         "arrang"
#  [913] "govern"        "level"         "pop"           "gotten"
#  [917] "hardli"        "accept"        "honest"        "won"
#  [921] "soul"          "attent"        "program"       "shoe"
#  [925] "bust"          "sheriff"       "univers"       "hunt"
#  [929] "feder"         "third"         "cat"           "load"
#  [933] "contact"       "discuss"       "mask"          "south"
#  [937] "afternoon"     "relationship"  "roll"          "commun"
#  [941] "singl"         "thou"          "sun"           "unit"
#  [945] "wind"          "shed"          "settl"         "depart"
#  [949] "bye"           "appear"        "insan"         "escap"
#  [953] "somethin"      "heaven"        "divorc"        "form"
#  [957] "definit"       "neck"          "spent"         "spot"
#  [961] "especi"        "imposs"        "hadnt"         "flight"
#  [965] "pal"           "dig"           "hildi"         "mister"
#  [969] "recogn"        "apolog"        "address"       "song"
#  [973] "um"            "tree"          "america"       "wire"
#  [977] "grab"          "note"          "action"        "gimm"
#  [981] "baron"         "silli"         "deep"          "b"
#  [985] "folk"          "press"         "sad"           "river"
#  [989] "twice"         "price"         "copi"          "within"
#  [993] "whether"       "lay"           "engin"         "bridg"
#  [997] "wow"           "sooner"        "flower"        "bunch"
# [1001] "gift"          "trap"          "plenti"        "cute"
# [1005] "grand"         "calm"          "stuck"         "difficult"
# [1009] "hero"          "suspect"       "mama"          "deserv"
# [1013] "aye"           "pardon"        "finger"        "wine"
# [1017] "area"          "sword"         "broken"        "ticket"
# [1021] "somehow"       "signal"        "cell"          "connect"
# [1025] "stole"         "comfort"       "proud"         "interview"
# [1029] "search"        "wound"         "split"         "empti"
# [1033] "weekend"       "tv"            "attract"       "birthday"
# [1037] "tear"          "pound"         "russian"       "chicken"
# [1041] "favorit"       "north"         "creatur"       "evid"
# [1045] "arriv"         "condit"        "beach"         "o"
# [1049] "judg"          "pilot"         "nurs"          "egg"
# [1053] "convers"       "rain"          "serious"       "size"
# [1057] "insur"         "goodnight"     "duti"          "bone"
# [1061] "bu"            "beyond"        "ga"            "dump"
# [1065] "shield"        "engag"         "magic"         "group"
# [1069] "continu"       "onto"          "superman"      "cook"
# [1073] "emerg"         "asleep"        "pretend"       "san"
# [1077] "enterpris"     "sea"           "base"          "desert"
# [1081] "fortun"        "organ"         "bug"           "bathroom"
# [1085] "ridicul"       "mountain"      "percent"       "confus"
# [1089] "sever"         "ourselv"       "career"        "author"
# [1093] "switch"        "bear"          "built"         "decis"
# [1097] "pocket"        "immedi"        "damag"         "colonel"
# [1101] "talkin"        "film"          "sailor"        "polit"
# [1105] "fell"          "advic"         "paint"         "heat"
# [1109] "charm"         "warm"          "map"           "gee"
# [1113] "cheap"         "collect"       "wing"          "sweetheart"
# [1117] "wild"          "expens"        "pool"          "centuri"
# [1121] "monster"       "nation"        "physic"        "detail"
# [1125] "guest"         "incred"        "forti"         "block"
# [1129] "fbi"           "vacat"         "bond"          "upstair"
# [1133] "purpos"        "bright"        "confess"       "whose"
# [1137] "vada"          "wash"          "bottl"         "emot"
# [1141] "main"          "correct"       "theori"        "view"
# [1145] "proof"         "camera"        "oil"           "access"
# [1149] "obvious"       "success"       "weak"          "moon"
# [1153] "odd"           "otherwis"      "effect"        "worst"
# [1157] "lookin"        "poison"        "thatll"        "green"
# [1161] "soldier"       "corner"        "toward"        "often"
# [1165] "match"         "televis"       "low"           "heavi"
# [1169] "assign"        "farm"          "credit"        "boyfriend"
# [1173] "assist"        "smile"         "sight"         "target"
# [1177] "dure"          "taught"        "greatest"      "rid"
# [1181] "investig"      "camp"          "hat"           "bite"
# [1185] "west"          "nerv"          "kitchen"       "profession"
# [1189] "climb"         "request"       "bloodi"        "retir"
# [1193] "hall"          "baxter"        "innoc"         "forward"
# [1197] "swim"          "due"           "develop"       "scene"
# [1201] "deliv"         "subject"       "freak"         "majesti"
# [1205] "lex"           "abov"          "lone"          "spare"
# [1209] "bullet"        "famou"         "shake"         "tight"
# [1213] "slip"          "held"          "crew"          "cousin"
# [1217] "speech"        "mysteri"       "cup"           "trade"
# [1221] "lift"          "nope"          "fella"         "newspap"
# [1225] "commit"        "includ"        "enter"         "suddenli"
# [1229] "trial"         "easier"        "peel"          "support"
# [1233] "loos"          "bath"          "locat"         "familiar"
# [1237] "excel"         "claim"         "sid"           "extra"
# [1241] "tower"         "hill"          "congratul"     "plant"
# [1245] "whom"          "draw"          "propos"        "receiv"
# [1249] "energi"        "page"          "battl"         "prefer"
# [1253] "east"          "spock"         "embarrass"     "transport"
# [1257] "victim"        "breakfast"     "foot"          "barn"
# [1261] "smith"         "intend"        "center"        "quarter"
# [1265] "introduc"      "monsieur"      "nail"          "suffer"
# [1269] "patient"       "bandit"        "player"        "disappoint"
# [1273] "gentleman"     "er"            "herself"       "itself"
# [1277] "member"        "whoever"       "trace"         "intellig"
# [1281] "faster"        "rent"          "desk"          "comin"
# [1285] "rate"          "strength"      "swell"         "plu"
# [1289] "thief"         "skin"          "marsh"         "wheel"
# [1293] "local"         "closer"        "convinc"       "int"
# [1297] "basebal"       "yo"            "pig"           "print"
# [1301] "quickli"       "weather"       "blade"         "itd"
# [1305] "medic"         "speed"         "lake"          "jone"
# [1309] "strike"        "jerk"          "repeat."       "terrif"
# [1313] "perform"       "truli"         "beam"          "celebr"
# [1317] "insist"        "wouldv"        "appar"         "object"
# [1321] "concentr"      "pant"          "driver"        "issu"
# [1325] "couldv"        "nah"           "lesson"        "research"
# [1329] "curiou"        "discov"        "scienc"        "starfleet"
# [1333] "common"        "approach"      "afford"        "separ"
# [1337] "mood"          "doubl"         "themselv"      "market"
# [1341] "lip"           "london"        "cab"           "fri"
# [1345] "project"       "gettin"        "forgotten"     "older"
# [1349] "equip"         "sudden"        "magazin"       "term"
# [1353] "guilti"        "clever"        "nightmar"      "languag"
# [1357] "whyd"          "drag"          "valu"          "releas"
# [1361] "tea"           "cream"         "til"           "civil"
# [1365] "threaten"      "wave"          "perfectli"     "ugli"
# [1369] "affair"        "invent"        "possess"       "airport"
# [1373] "plate"         "rush"          "defend"        "aunt"
# [1377] "client"        "teeth"         "confirm"       "choos"
# [1381] "saturday"      "spirit"        "upon"          "comrad"
# [1385] "dude"          "sold"          "negoti"        "billion"
# [1389] "tunnel"        "deed"          "scream"        "chair"
# [1393] "stock"         "yep"           "squar"         "seal"
# [1397] "everywher"     "charact"       "italian"       "style"
# [1401] "post"          "custom"        "opinion"       "photograph"
# [1405] "edg"           "refus"         "pure"          "crawl"
# [1409] "dozen"         "sport"         "degre"         "nowher"
# [1413] "properti"      "willow"        "obviou"        "tour"
# [1417] "larg"          "throat"        "dri"           "england"
# [1421] "eleven"        "mostli"        "pair"          "miracl"
# [1425] "defens"        "villag"        "complic"       "intent"
# [1429] "cent"          "basic"         "contract"      "bare"
# [1433] "spoke"         "whoa"          "dinosaur"      "ranch"
# [1437] "licens"        "mitch"         "wherev"        "california"
# [1441] "coat"          "frighten"      "secretari"     "chip"
# [1445] "inde"          "justic"        "professor"     "regular"
# [1449] "bat"           "rome"          "suppli"        "design"
# [1453] "dare"          "jealou"        "stare"         "awhil"
# [1457] "washington"    "shoulder"      "spring"        "fan"
# [1461] "rang"          "tip"           "transfer"      "rough"
# [1465] "opportun"      "senat"         "princess"      "neg"
# [1469] "liar"          "statement"     "pill"          "desper"
# [1473] "shouldv"       "betray"        "leader"        "lawson"
# [1477] "shower"        "someplac"      "becam"         "snake"
# [1481] "british"       "friendli"      "necessari"     "ignor"
# [1485] "shape"         "trail"         "resist"        "biggest"
# [1489] "social"        "sourc"         "weight"        "militari"
# [1493] "uyouu"         "offici"        "diamond"       "mix"
# [1497] "citizen"       "oughta"        "further"       "activ"
# [1501] "whatta"        "sixti"         "fake"          "seek"
# [1505] "romant"        "among"         "freez"         "mustv"
# [1509] "gang"          "neighbor"      "vampir"        "zone"
# [1513] "offens"        "threw"         "band"          "particular"
# [1517] "unfortun"      "bottom"        "nuclear"       "bless"
# [1521] "freedom"       "intern"        "yard"          "cowboy"
# [1525] "borrow"        "race"          "event"         "recal"
# [1529] "worm"          "lover"         "understood"    "hmm"
# [1533] "emperor"       "cure"          "challeng"      "confid"
# [1537] "europ"         "launch"        "lampert"       "knee"
# [1541] "bay"           "simpli"        "talent"        "chick"
# [1545] "snow"          "actor"         "brave"         "schedul"
# [1549] "fighter"       "avoid"         "mayor"         "realiti"
# [1553] "mirror"        "milk"          "whenev"        "neighborhood"
# [1557] "origin"        "wood"          "stolen"        "crowd"
# [1561] "self"          "product"       "robinson"      "princ"
# [1565] "express"       "garden"        "imag"          "femal"
# [1569] "storm"         "rat"           "eighteen"      "shock"
# [1573] "gut"           "teacher"       "jacket"        "squad"
# [1577] "lenni"         "contain"       "pray"          "friday"
# [1581] "relat"         "stranger"      "knowledg"      "museum"
# [1585] "recommend"     "tank"          "attitud"       "brown"
# [1589] "fed"           "restaur"       "clock"         "cia"
# [1593] "process"       "ghost"         "leagu"         "nor"
# [1597] "attempt"       "cheer"         "piti"          "dunno"
# [1601] "fresh"         "da"            "accord"        "el"
# [1605] "limit"         "shame"         "telephon"      "pump"
# [1609] "unusu"         "soft"          "wise"          "advanc"
# [1613] "prom"          "assur"         "attorney"      "aboard"
# [1617] "horribl"       "wolf"          "extrem"        "luthor"
# [1621] "empir"         "holiday"       "thinkin"       "stage"
# [1625] "grate"         "cow"           "spi"           "mail"
# [1629] "pregnant"      "awar"          "cooper"        "deck"
# [1633] "kidnap"        "tall"          "priest"        "blew"
# [1637] "dyou"          "exit"          "wet"           "amount"
# [1641] "shift"         "alvi"          "score"         "mar"
# [1645] "border"        "counti"        "sunday"        "bleed"
# [1649] "grail"         "rip"           "requir"        "writer"
# [1653] "elev"          "wipe"          "sergeant"      "stomach"
# [1657] "destini"       "captur"        "passion"       "rescu"
# [1661] "juic"          "kit"           "johnson"       "polici"
# [1665] "coke"          "ocean"         "fuel"          "cage"
# [1669] "clearli"       "lousi"         "identifi"      "msieu"
# [1673] "materi"        "statu"         "fate"          "nearli"
# [1677] "graduat"       "castl"         "chicago"       "batman"
# [1681] "piano"         "permiss"       "sixteen"       "screen"
# [1685] "tail"          "jet"           "punch"         "termin"
# [1689] "replac"        "rope"          "vulcan"        "hmmm"
# [1693] "thursday"      "sin"           "slept"         "drown"
# [1697] "alarm"         "lab"           "satisfi"       "fort"
# [1701] "buzz"          "shirt"         "wallet"        "earlier"
# [1705] "gear"          "midnight"      "remov"         "below"
# [1709] "sky"           "boot"          "china"         "drove"
# [1713] "downstair"     "russia"        "photo"         "radiat"
# [1717] "sneak"         "pin"           "mmm"           "season"
# [1721] "vega"          "gallagh"       "reput"         "guarante"
# [1725] "monday"        "regret"        "indian"        "batteri"
# [1729] "repres"        "cloud"         "mexico"        "someday"
# [1733] "bud"           "describ"       "legal"         "uniform"
# [1737] "cake"          "brilliant"     "sand"          "lombard"
# [1741] "threat"        "nois"          "confer"        "texa"
# [1745] "occur"         "argu"          "grew"          "wynant"
# [1749] "meat"          "harm"          "foolish"       "depress"
# [1753] "twentyf"       "reward"        "garbag"        "honestli"
# [1757] "observ"        "geniu"         "recent"        "guid"
# [1761] "insult"        "marylin"       "appoint"       "provid"
# [1765] "crow"          "brand"         "tool"          "model"
# [1769] "lad"           "logic"         "thatd"         "lemm"
# [1773] "royal"         "pattern"       "rare"          "fund"
# [1777] "disk"          "pressur"       "howev"         "promot"
# [1781] "lifetim"       "button"        "written"       "snap"
# [1785] "fashion"       "eventu"        "shoulda"       "scientist"
# [1789] "shadow"        "exact"         "scar"          "casablanca"
# [1793] "gain"          "meal"          "sugar"         "explor"
# [1797] "flat"          "mommi"         "compliment"    "passport"
# [1801] "vote"          "male"          "devic"         "wander"
# [1805] "bedroom"       "estat"         "trunk"         "option"
# [1809] "function."     "parker"        "loud"          "fenc"
# [1813] "channel"       "precog"        "malkovich"     "solid"
# [1817] "ninotchka"     "younger"       "bell"          "scratch"
# [1821] "jam"           "popular"       "iii"           "obsess"
# [1825] "territori"     "zero"          "although"      "swing"
# [1829] "fought"        "preys"         "yuh"           "surrend"
# [1833] "ate"           "roof"          "artist"        "loan"
# [1837] "blast"         "focu"          "march"         "reveng"
# [1841] "mac"           "champagn"      "railroad"      "lo"
# [1845] "viru"          "bum"           "zoo"           "scan"
# [1849] "palac"         "courag"        "cave"          "hudson"
# [1853] "underground"   "navi"          "iraqi"         "expert"
# [1857] "ta"            "higher"        "instruct"      "saavik"
# [1861] "birth"         "makin"         "circumst"      "maya"
# [1865] "ancient"       "skip"          "downtown"      "agenc"
# [1869] "shelter"       "associ"        "per"           "rabbit"
# [1873] "habit"         "convict"       "abandon"       "torpedo"
# [1877] "fifth"         "curs"          "creasi"        "hawk"
# [1881] "corpor"        "tellin"        "safeti"        "distanc"
# [1885] "coast"         "genesi"        "spell"         "thrill"
# [1889] "destruct"      "frozen"        "miser"         "result"
# [1893] "moral"         "badg"          "pour"          "network"
# [1897] "vice"          "pen"           "rise"          "metal"
# [1901] "opera"         "nobl"          "invest"        "woke"
# [1905] "lower"         "chain"         "crook"         "video"
# [1909] "fascin"        "fulli"         "awak"          "cheat"
# [1913] "indi"          "earn"          "trigger"       "kip"
# [1917] "asham"         "monitor"       "patienc"       "fantast"
# [1921] "student"       "sweat"         "thumb"         "sat"
# [1925] "sale"          "firm"          "led"           "societi"
# [1929] "thee"          "fleet"         "stake"         "seventeen"
# [1933] "rig"           "treasur"       "doll"          "walli"
# [1937] "mental"        "monkey"        "progress"      "yell"
# [1941] "examin"        "senior"        "panic"         "shhh"
# [1945] "alert"         "smash"         "directli"      "stair"
# [1949] "coordin"       "complain"      "precis"        "orang"
# [1953] "toy"           "bail"          "entertain"     "wagon"
# [1957] "director"      "abil"          "ape"           "silver"
# [1961] "kong"          "ad"            "santa"         "mere"
# [1965] "clue"          "document"      "central"       "chop"
# [1969] "articl"        "fanci"         "tag"           "tradit"
# [1973] "pathet"        "capabl"        "stink"         "sector"
# [1977] "sore"          "appl"          "creep"         "headach"
# [1981] "s"             "packag"        "sampl"         "speci"
# [1985] "zira"          "grave"         "float"         "bull"
# [1989] "psycho"        "glori"         "slowli"        "berlin"
# [1993] "spoken"        "friedman"      "psychic"       "foreign"
# [1997] "X30"           "bodyguard"     "frankli"       "inspir"
# [2001] "edi"           "yellow"        "plastic"       "winter"
# [2005] "grade"         "link"          "warrior"       "punish"
# [2009] "poem"          "neo"           "tini"          "tax"
# [2013] "ms"            "gate"          "combin"        "bound"
# [2017] "circl"         "rout"          "spoil"         "interrupt"
# [2021] "sandwich"      "exercis"       "refer"         "huge"
# [2025] "exampl"        "standard"      "easili"        "gum"
# [2029] "kringelein"    "add"           "nonsens"       "port"
# [2033] "eighti"        "demand"        "librari"       "compar"
# [2037] "profit"        "hidden"        "avail"         "blown"
# [2041] "dust"          "iron"          "initi"         "rub"
# [2045] "maid"          "effort"        "stood"         "construct"
# [2049] "sensit"        "rel"           "pie"           "ident"
# [2053] "bowl"          "attend"        "commiss"       "st"
# [2057] "moscow"        "procedur"      "blond"         "tryin"
# [2061] "flatter"       "satellit"      "t"             "bride"
# [2065] "stew"          "loss"          "warp"          "reserv"
# [2069] "therel"        "fourteen"      "electr"        "proper"
# [2073] "healthi"       "decent"        "wreck"         "thin"
# [2077] "behavior"      "naw"           "jersey"        "affect"
# [2081] "advis"         "cancel"        "particularli"  "laszlo"
# [2085] "spread"        "garag"         "valuabl"       "health"
# [2089] "stretch"       "helicopt"      "workin"        "technic"
# [2093] "kubelik"       "gosh"          "belt"          "sock"
# [2097] "backup"        "starv"         "kat"           "tuesday"
# [2101] "cultur"        "exchang"       "yup"           "nest"
# [2105] "crush"         "accus"         "morpheu"       "dealer"
# [2109] "rank"          "industri"      "ador"          "manner"
# [2113] "sheet"         "chocol"        "instinct"      "sacrific"
# [2117] "altern"        "pet"           "cabl"          "impuls"
# [2121] "magnific"      "adventur"      "inch"          "unhappi"
# [2125] "knox"          "civilian"      "vision"        "pirat"
# [2129] "disast"        "surfac"        "frame"         "armor"
# [2133] "rafe"          "dyle"          "mate"          "sweeti"
# [2137] "flip"          "bid"           "expos"         "ahh"
# [2141] "cast"          "routin"        "alien"         "determin"
# [2145] "fox"           "prevent"       "hack"          "educ"
# [2149] "dartagnan"     "stronger"      "ordinari"      "humor"
# [2153] "badli"         "footbal"       "behav"         "silenc"
# [2157] "preciou"       "rude"          "flame"         "respond"
# [2161] "lunat"         "scout"         "nineteen"      "surgeon"
# [2165] "sink"          "produc"        "bargain"       "valley"
# [2169] "whod"          "cap"           "golden"        "recov"
# [2173] "competit"      "vessel"        "westley"       "marqui"
# [2177] "financi"       "fortress"      "clown"         "proceed"
# [2181] "duck"          "presenc"       "motiv"         "asid"
# [2185] "handsom"       "klingon"       "scari"         "champion"
# [2189] "flash"         "stu"           "ambassador"    "foley"
# [2193] "skill"         "chees"         "duff"          "pink"
# [2197] "predict"       "bein"          "movement"      "regist"
# [2201] "giant"         "explan"        "flow"          "grown"
# [2205] "heal"          "humili"        "thrown"        "genet"
# [2209] "minist"        "fee"           "entranc"       "wednesday"
# [2213] "dna"           "re"            "singer"        "employ"
# [2217] "specif"        "solut"         "element"       "plain"
# [2221] "publish"       "buckaroo"      "hollywood"     "m"
# [2225] "staff"         "sensor"        "dull"          "advantag"
# [2229] "sacr"          "mass"          "mug"           "interfer"
# [2233] "rumor"         "thorwald"      "sentiment"     "chemic"
# [2237] "bureau"        "oblig"         "signatur"      "incid"
# [2241] "merci"         "sheldrak"      "simul"         "classic"
# [2245] "struck"        "titl"          "winner"        "twist"
# [2249] "sail"          "continued."    "itali"         "tran"
# [2253] "mccoy"         "noon"          "profil"        "motel"
# [2257] "alter"         "appli"         "rico"          "hong"
# [2261] "grandma"       "diari"         "saint"         "gambl"
# [2265] "dock"          "matrix"        "psycholog"     "aim"
# [2269] "anytim"        "rifl"          "editor"        "coincid"
# [2273] "strip"         "spice"         "eras"          "cabin"
# [2277] "detroit"       "individu"      "turkey"        "prize"
# [2281] "tune"          "drill"         "averag"        "inna"
# [2285] "visa"          "dirt"          "powder"        "quot"
# [2289] "calcul"        "toss"          "string"        "wore"
# [2293] "stab"          "coulda"        "tan"           "meter"
# [2297] "j"             "path"          "complex"       "shuttl"
# [2301] "surround"      "riot"          "blank"         "venic"
# [2305] "traffic"       "mora"          "thisll"        "employe"
# [2309] "cougar"        "highli"        "happili"       "tone"
# [2313] "borg"          "wide"          "spray"         "juri"
# [2317] "stamp"         "avenu"         "journey"       "takin"
# [2321] "former"        "jewelri"       "safer"         "log"
# [2325] "ti"            "plagu"         "regard"        "mutant"
# [2329] "lobbi"         "vigo"          "spider"        "maverick"
# [2333] "salt"          "defeat"        "dish"          "dime"
# [2337] "rotten"        "donut"         "permit"        "volunt"
# [2341] "chest"         "theatr"        "announc"       "audienc"
# [2345] "peanut"        "structur"      "oneil"         "mayo"
# [2349] "venkman"       "twentyfour"    "atmospher"     "chairman"
# [2353] "miami"         "anyhow"        "breaker"       "te"
# [2357] "whatll"        "mighti"        "shotgun"       "coward"
# [2361] "plot"          "opposit"       "aid"           "steadi"
# [2365] "inn"           "picard"        "occas"         "elect"
# [2369] "lotta"         "afterward"     "disgust"       "duke"
# [2373] "capit"         "superior"      "carrier"       "seduc"
# [2377] "buffi"         "seventi"       "section"       "cigar"
# [2381] "vehicl"        "romulan"       "indic"         "goal"
# [2385] "goat"          "breed"         "anger"         "flesh"
# [2389] "etern"         "warrant"       "selfish"       "norvil"
# [2393] "worf"          "fabul"         "sulu"          "del"
# [2397] "sharp"         "pleasant"      "perman"        "howr"
# [2401] "puppet"        "heel"          "factori"       "shrink"
# [2405] "ol"            "symbol"        "combat"        "jungl"
# [2409] "psychiatrist"  "legend"        "mmmm"          "mayflow"
# [2413] "jedi"          "X100"          "nineti"        "tale"
# [2417] "ultim"         "schwartz"      "victori"       "X20"
# [2421] "bourn"         "dancer"        "pge"           "occasion"
# [2425] "aggress"       "tourist"       "episod"        "conscienc"
# [2429] "potenti"       "fallen"        "solv"          "missil"
# [2433] "camel"         "darlin"        "current"       "coach"
# [2437] "blah"          "reaction"      "bend"          "eastern"
# [2441] "mortal"        "silent"        "hostil"        "forest"
# [2445] "sentenc"       "eaten"         "grandmoth"     "paranoid"
# [2449] "purs"          "robberi"       "mig"           "gather"
# [2453] "rag"           "lednov"        "fingerprint"   "distract"
# [2457] "accomplish"    "locker"        "patch"         "union"
# [2461] "honeymoon"     "alley"         "delay"         "commerci"
# [2465] "costum"        "bunni"         "starship"      "grey"
# [2469] "dame"          "orbit"         "worthi"        "tribun"
# [2473] "neutral"       "loyalti"       "principl"      "goddam"
# [2477] "forbidden"     "chekov"        "needl"         "compound"
# [2481] "bluff"         "equal"         "feelin"        "fourth"
# [2485] "embassi"       "mon"           "tiger"         "musta"
# [2489] "began"         "ganz"          "miller"        "marvel"
# [2493] "seri"          "toto"          "consider"      "adjust"
# [2497] "thirteen"      "haul"          "veget"         "angl"
# [2501] "lack"          "useless"       "pitch"         "poetri"
# [2505] "shi"           "helluva"       "chew"          "chewi"
# [2509] "valiant"       "expedit"       "goos"          "suspici"
# [2513] "temperatur"    "scale"         "knight"        "le"
# [2517] "poker"         "instant"       "instanc"       "conduct"
# [2521] "ranger"        "passag"        "hip"           "tap"
# [2525] "repair"        "wrap"          "vader"         "chat"
# [2529] "prayer"        "cattl"         "tend"          "vinci"
# [2533] "mistaken"      "root"          "council"       "twin"
# [2537] "extraordinari" "razor"         "raoul"         "dawson"
# [2541] "liberti"       "madmartigan"   "precrim"       "oath"
# [2545] "coloni"        "jeep"          "version"       "policeman"
# [2549] "distress"      "flew"          "farmer"        "scientif"
# [2553] "measur"        "sonora"        "seventyf"      "tube"
# [2557] "achiev"        "ditch"         "ext"           "gotham"
# [2561] "steel"         "soap"          "laser"         "amus"
# [2565] "theo"          "paradis"       "epp"           "magua"
# [2569] "grandfath"     "whack"         "enzo"          "super"
# [2573] "shave"         "exhaust"       "chamber"       "grunemann"
# [2577] "bachelor"      "li"            "pride"         "mm"
# [2581] "argument"      "core"          "ouch"          "dispos"
# [2585] "ripley"        "phaser"        "driven"        "violent"
# [2589] "violat"        "lean"          "deputi"        "martini"
# [2593] "ex"            "worker"        "czech"         "wanta"
# [2597] "conclus"       "unlik"         "acknowledg"    "harbor"
# [2601] "kansa"         "site"          "swana"         "swamp"
# [2605] "appeal"        "bean"          "alpha"         "properli"
# [2609] "widow"         "gentl"         "convent"       "delight"
# [2613] "bailey"        "improv"        "X24"           "corridor"
# [2617] "shakespear"    "payment"       "fantasi"       "eas"
# [2621] "X67"           "unbeliev"      "ambros"        "woulda"
# [2625] "architect"     "outfit"        "patrol"        "pipe"
# [2629] "collar"        "benefit"       "hop"           "d"
# [2633] "subway"        "spanish"       "prime"         "surgeri"
# [2637] "ace"           "terrifi"       "worthless"     "superhero"
# [2641] "deliveri"      "chopper"       "ethic"         "shown"
# [2645] "yourselv"      "governor"      "user"          "envelop"
# [2649] "toast"         "novel"         "visitor"       "sorta"
# [2653] "uniqu"         "bread"         "uncomfort"     "phase"
# [2657] "con"           "clinic"        "phoni"         "mu"
# [2661] "poet"          "rubber"        "trash"         "bark"
# [2665] "rocket"        "experienc"     "injur"         "cuervo"
# [2669] "soup"          "ringo"         "creed"         "cobb"
# [2673] "straighten"    "golf"          "wherer"        "consequ"
# [2677] "recruit"       "cannon"        "bitter"        "mechan"
# [2681] "inspector"     "X7"            "fare"          "tent"
# [2685] "domino"        "punk"          "oswald"        "belli"
# [2689] "unicorn"       "romanc"        "couch"         "pope"
# [2693] "schuyler"      "whisper"       "zack"          "flyer"
# [2697] "waitin"        "divis"         "fairli"        "transmiss"
# [2701] "visual"        "evolv"         "candid"        "chosen"
# ...
# [4109] "panel"         "lodg"          "transmitt"     "glow"
# [4113] "farther"       "roper"         "alamo"         "cord"
# [4117] "eiffel"        "quantum"       "signific"      "contribut"
# [4121] "stir"          "lighten"       "lighter"       "shaft"
# [4125] "immun"         "op"            "imperfect"     "reckon"
# [4129] "react"         "lemon"         "pasta"         "disabl"
# [4133] "bodhi"         "footag"        "branch"        "meaningless"
# [4137] "symphoni"      "uwhyu"         "modest"        "allerg"
# [4141] "sauc"          "unemploy"      "k"             "sleepi"
# [4145] "creek"         "paperwork"     "gown"          "X90"
# [4149] "conscious"     "gunshot"       "yessir"        "poach"
# [4153] "X2000"         "th"            "hirsch"        "squirrel"
# [4157] "error"         "smuggl"        "decad"         "tenth"
# [4161] "slayer"        "novemb"        "vein"          "pinch"
# [4165] "crunch"        "recoveri"      "nomin"         "ingen"
# [4169] "cappuccino"    "septemb"       "wax"           "charenton"
# [4173] "repriev"       "hyster"        "cal"           "pacif"
# [4177] "excess"        "mourn"         "chrissak"      "albani"
# [4181] "cellular"      "duncan"        "implic"        "shred"
# [4185] "cramp"         "torn"          "garter"        "drexl"
# [4189] "aveng"         "gibarian"      "affirm"        "protocol"
# [4193] "immigr"        "analyst"       "deceas"        "careless"
# [4197] "X18"           "secondari"     "smear"         "swede"
# [4201] "casualti"      "deem"          "u"             "ramel"
# [4205] "cockroach"     "fiction"       "iim"           "alik"
# [4209] "courtroom"     "disagre"       "gibson"        "goddess"
# [4213] "umyu"          "siddown"       "globe"         "naiv"
# [4217] "scobi"         "composit"      "filter"        "magda"
# [4221] "sanctuari"     "newt"          "portal"        "extract"
# [4225] "sunlight"      "cledu"         "childhood"     "rosalin"
# [4229] "jazz"          "impati"        "justifi"       "knowi"
# [4233] "oona"          "instructor"    "complaint"     "garber"
# [4237] "sip"           "echo"          "morlock"       "thug"
# [4241] "obtain"        "tch"           "herd"          "dork"
# [4245] "navig"         "doublecross"   "interpret"     "rider"
# [4249] "currenc"       "X2"            "rival"         "atom"
# [4253] "slot"          "landlord"      "bundl"         "bundi"
# [4257] "shreck"        "ohh"           "au"            "incap"
# [4261] "vic"           "gallon"        "condemn"       "ith"
# [4265] "lantern"       "slick"         "impact"        "chevali"
# [4269] "wholl"         "supervisor"    "earp"          "soak"
# [4273] "lust"          "dreyfuss"      "ohiggin"       "championship"
# [4277] "spooki"        "greed"         "airk"          "viznick"
# [4281] "tragedi"       "kenworth"      "uhoh"          "casual"
# [4285] "ego"           "grime"         "lit"           "awesom"
# [4289] "cuff"          "havin"         "manipul"       "fuzzi"
# [4293] "daikini"       "shh"           "talley"        "serial"
# [4297] "hunch"         "thankyou"      "massiv"        "nevada"
# [4301] "mcp"           "dash"          "ir"            "psych"
# [4305] "wretch"        "earthquak"     "burk"          "keeper"
# [4309] "bloke"         "caravaggio"    "spiderman"     "oppon"
# [4313] "tennesse"      "tub"           "graveyard"     "einstein"
# [4317] "binocular"     "keepin"        "surfer"        "wager"
# [4321] "plead"         "mikey"         "chemistri"     "gratitud"
# [4325] "brazil"        "scandal"       "miyamoto"      "dat"
# [4329] "buster"        "virtual"       "roston"        "orphan"
# [4333] "countess"      "treati"        "bind"          "reconstruct"
# [4337] "expertis"      "ich"           "corn"          "reli"
# [4341] "waddaya"       "ventur"        "religi"        "hinkley"
# [4345] "suspend"       "pri"           "campbel"       "britain"
# [4349] "bulli"         "taupin"        "expir"         "carlotta"
# [4353] "overlook"      "po"            "discourag"     "nasa"
# [4357] "ladyship"      "carrot"        "xray"          "bronx"
# [4361] "layer"         "annual"        "strasser"      "wooden"
# [4365] "gorman"        "thunder"       "cult"          "tremend"
# [4369] "traver"        "adapt"         "rice"          "doth"
# [4373] "udal"          "endur"         "legitim"       "papa"
# [4377] "instal"        "enhanc"        "prenup"        "boulevard"
# [4381] "dreamer"       "lawn"          "merit"         "transact"
# [4385] "hoover"        "defi"          "intel"         "exil"
# [4389] "hee"           "heh"           "tricki"        "quicker"
# [4393] "yakushova"     "bypass"        "exposit"       "spiritu"
# [4397] "limo"          "dumbest"       "robot"         "thigh"
# [4401] "insight"       "length"        "spain"         "android"
# [4405] "ing"           "bro"           "l"             "guild"
# [4409] "deepest"       "oldfashion"    "helpless"      "pillow"
# [4413] "sweeney"       "tragic"        "monkeybon"     "monk"
# [4417] "gloriou"       "sixth"         "fugit"         "X3000"
# [4421] "sybok"         "marvosa"       "restless"      "birdson"
# [4425] "whatsoev"      "grang"         "resolv"        "syndrom"
# [4429] "gent"          "fridg"         "starter"       "knowin"
# [4433] "sought"        "discharg"      "marseil"       "skunk"
# [4437] "crate"         "rash"          "powwow"        "stumbl"
# [4441] "trucker"       "wimp"          "kittridg"      "schmuck"
# [4445] "lonesom"       "harass"        "stalker"       "seed"
# [4449] "mushu"         "brigad"        "hartman"       "cochran"
# [4453] "sunk"          "taho"          "pard"          "silo"
# [4457] "amnesia"       "X300"          "grammi"        "resembl"
# [4461] "fetch"         "que"           "malfunct"      "fright"
# [4465] "pepper"        "mccaffrey"     "spike"         "vapor"
# [4469] "seminar"       "vietnam"       "vital"         "buyer"
# [4473] "microscop"     "tron"          "weep"          "michigan"
# [4477] "uimu"          "egyptian"      "sophomor"      "iranoff"
# [4481] "tsch"          "artifici"      "buffalo"       "session"
# [4485] "patron"        "darkest"       "sweeter"       "perspect"
# [4489] "academ"        "theme"         "bookstor"      "givin"
# [4493] "falcon"        "despair"       "serafin"       "droid"
# [4497] "reman"         "wheelchair"    "butterfli"     "exagger"
# [4501] "almighti"      "persist"       "warehous"      "econom"
# [4505] "brutal"        "backyard"      "lifestyl"      "ambiti"
# [4509] "shorter"       "hemingway"     "supernatur"    "slim"
# [4513] "bent"          "partnership"   "claremont"     "spose"
# [4517] "intrigu"       "autom"         "bishop"        "beryllium"
# [4521] "consent"       "handcuff"      "bartend"       "grandpa"
# [4525] "yeh"           "d6"            "physician"     "plasma"
# [4529] "threepio"      "geordi"        "sheep"         "postcard"
# [4533] "comparison"    "underwat"      "carpet"        "gazzo"
# [4537] "embrac"        "skywalk"       "lightn"        "finer"
# [4541] "wacko"         "basi"          "elder"         "kindli"
# [4545] "antiqu"        "cleaner"       "cartwright"    "vibe"
# [4549] "fastest"       "fortytwo"      "keen"          "luc"
# [4553] "furnitur"      "snicker"       "burden"        "unlock"
# [4557] "crummi"        "decemb"        "accur"         "altitud"
# [4561] "substanc"      "coup"          "minim"         "bellerophon"
# [4565] "is."           "richest"       "imim"          "diz"
# [4569] "ridin"         "plaza"         "bolshevik"     "agit"
# [4573] "cuban"         "tuck"          "imperi"        "parlor"
# [4577] "sunris"        "elektra"       "howl"          "carpent"
# [4581] "farragut"      "lime"          "lapd"          "verifi"
# [4585] "bench"         "ravel"         "sofa"          "hassl"
# [4589] "hath"          "difficulti"    "connecticut"   "mercuri"
# [4593] "consol"        "coil"          "waltz"         "geek"
# [4597] "pardner"       "donat"         "asta"          "appetit"
# [4601] "stenograph"    "X1000"         "connor"        "infant"
# [4605] "dya"           "amend"         "lookout"       "detour"
# [4609] "reconsid"      "suprem"        "nba"           "penalti"
# [4613] "statist"       "breakin"       "motorcycl"     "pollux"
# [4617] "paw"           "ambit"         "tension"       "accent"
# [4621] "junki"         "richi"         "uareu"         "et"
# [4625] "endang"        "arrow"         "dugan"         "sensibl"
# [4629] "creativ"       "role"          "dusti"         "disconnect"
# [4633] "mantini"       "sponsor"       "byeby"         "panick"
# [4637] "thirtyeight"   "homeless"      "gingham"       "morg"
# [4641] "brumbi"        "kensington"    "overtim"       "eleg"
# [4645] "bingi"         "ui"            "slit"          "strateg"
# [4649] "messeng"       "courtesi"      "jad"           "debi"
# [4653] "souvenir"      "banish"        "dam"           "vain"
# [4657] "kiddo"         "assess"        "munro"         "zander"
# [4661] "shiit"         "vagu"          "fuse"          "retreat"
# [4665] "khan"          "braslow"       "heller"        "pankot"
# [4669] "clanton"       "multipl"       "lyin"          "carv"
# [4673] "slam"          "razinin"       "proven"        "essenc"
# [4677] "arena"         "duh"           "substanti"     "ninja"
# [4681] "blush"         "nuthin"        "sneakin"       "northern"
# [4685] "delus"         "rambo"         "feller"        "leash"
# [4689] "bacon"         "sixtyf"        "winch"         "vase"
# [4693] "vitelli"       "climat"        "wage"          "sorsha"
# [4697] "cosmic"        "gambler"       "louder"        "hunger"
# [4701] "enchant"       "gasolin"       "X31"           "dreamt"
# [4705] "unnecessari"   "interv"        "vacuum"        "jealousi"
# [4709] "dodg"          "shook"         "reynold"       "lowri"
# [4713] "frequent"      "housekeep"     "broadcast"     "squat"
# [4717] "hmmmm"         "coupon"        "striker"       "havana"
# [4721] "X5000"         "lysin"         "happiest"      "copper"
# [4725] "dentist"       "theft"         "quell"         "kopalski"
# [4729] "curb"          "powel"         "miz"           "prais"
# [4733] "nevertheless"  "adm"           "peddl"         "craft"
# [4737] "soda"          "thoroughli"    "spite"         "delli"
# [4741] "rodent"        "plumber"       "refriger"      "boast"
# [4745] "visibl"        "merchandis"    "mandrak"       "gulf"
# [4749] "berri"         "bummer"        "fender"        "weed"
# [4753] "disrupt"       "whend"         "sensenet"      "bizarr"
# [4757] "v"             "resort"        "interrog"      "swipe"
# [4761] "necklac"       "gild"          "X70"           "jeanloui"
# [4765] "momma"         "ralli"         "flaemm"        "yoda"
# [4769] "disgrac"       "zowi"          "prosecut"      "tamper"
# [4773] "oui"           "clone"         "extermin"      "cuba"
# [4777] "crude"         "jog"           "largest"       "heavili"
# [4781] "sarri"         "herb"          "X99"           "chump"
# [4785] "siberia"       "wisdom"        "reassur"       "colet"
# [4789] "happenin"      "tuna"          "ooooh"         "janosz"
# [4793] "bandag"        "carriag"       "behalf"        "webster"
# [4797] "gaff"          "slob"          "clau"          "ab"
# [4801] "reader"        "smartest"      "buttercup"     "bubbl"
# [4805] "cartoon"       "hollow"        "dobisch"       "corvi"
# [4809] "inclin"        "sultenfuss"    "cremat"        "peke"
# [4813] "standin"       "lazi"          "columbia"      "onion"
# [4817] "varieti"       "hypocrit"      "sallah"        "recreat"
# [4821] "stead"         "fragil"        "rail"          "diner"
# [4825] "kuato"         "deflector"     "southern"      "undead"
# [4829] "frontier"      "rembrandt"     "puff"          "endors"
# [4833] "zorg"          "overnight"     "trailer"       "harmsway"
# [4837] "fiance"        "mercutio"      "nurtur"        "experiment"
# [4841] "sicili"        "fhloston"      "balloon"       "balboa"
# [4845] "burbag"        "mississippi"   "nintendo"      "elimin"
# [4849] "reagan"        "hoop"          "uyouru"        "dumber"
# [4853] "vitamin"       "warden"        "revel"         "bookkeep"
# [4857] "bold"          "uthinku"       "stallion"      "perk"
# [4861] "flu"           "shatter"       "montoya"       "yield"
# [4865] "derang"        "munci"         "thatthat"      "dew"
# [4869] "socal"         "drain"         "ireland"       "neutron"
# [4873] "grid"          "duct"          "mayonnais"     "intercept"
# [4877] "harvest"       "aft"           "lib"           "muddi"
# [4881] "hideou"        "insert"        "oconnel"       "noisi"
# [4885] "harvard"       "lure"          "barbecu"       "cockpit"
# [4889] "ancestor"      "precaut"       "flop"          "outstand"
# [4893] "drivin"        "disposit"      "unstabl"       "dent"
# [4897] "baku"          "one."          "kelson"        "plaintiff"
# [4901] "twofac"        "hum"           "hut"           "pre"
# [4905] "freshman"      "formula"       "pinkerton"     "hump"
# [4909] "sentri"        "stalk"         "kessler"       "psychiatr"
# [4913] "theoret"       "crusad"        "inmat"         "hitter"
# [4917] "myth"          "extort"        "climber"       "caution"
# [4921] "surgic"        "burial"        "silicon"       "freelanc"
# [4925] "dummi"         "tech"          "lethal"        "manson"
# [4929] "lookit"        "altar"         "tombston"      "suffici"
# [4933] "pasadena"      "dimens"        "prosecutor"    "biolog"
# [4937] "babysit"       "goodman"       "jahn"          "barber"
# [4941] "shhhhh"        "grub"          "lobster"       "rebuild"
# [4945] "lent"          "gurney"        "tranquil"      "brotherhood"
# [4949] "sang"          "defect"        "metabol"       "arson"
# [4953] "blender"       "overboard"     "lash"          "perpetu"
# [4957] "vou"           "intuit"        "abduct"        "constantinopl"
# [4961] "trubshaw"      "spaghetti"     "nexu"          "two."
# [4965] "jaw"           "lawsuit"       "doorway"       "indict"
# [4969] "demolit"       "guinan"        "peak"          "philosoph"
# [4973] "divert"        "cottag"        "soran"         "webber"
# [4977] "coop"          "wh"            "wu"            "subscrib"
# [4981] "yengees"       "poss"          "absenc"        "kitten"
# [4985] "octob"         "wealthi"       "ironi"         "argo"
# [4989] "blink"         "delic"         "deuc"          "pumpkin"
# [4993] "bodega"        "wheat"         "pitcher"       "mamma"
# [4997] "foster"        "pub"           "vegetarian"    "garrison"
# [5001] "grammoo"       "chimney"       "bikini"        "richter"
# [5005] "psychopath"    "fling"

# %%
# finding the column index of a word (and to check if a word is there or not)
match( 'gun', cols)
# Out:
# [1] NA

# %%
# scatter plot: the frequency of 'love' on x-axis, 'robberi' on y-axis, color of points corresponds to genre

ggplot( training_data, aes( x = robberi, y = love, color=Genre)) + geom_point( position = 'jitter')

# Observation: if love > 0.005, likely to be romance; if roberri > 0.0003, likely to be action
# Out:
# plot without title

# %%
# scatter plot 2

ggplot( training_data, aes( x = robberi, y = motel, color=Genre)) + geom_point( position = 'jitter')
# Out:
# plot without title

# %%
# scatter plot 3

ggplot( training_data, aes( x = prison, y = motel, color=Genre)) + geom_point( position = 'jitter')

# motel > 0.0004 -> action; prison > 0.0005 -> action
# Out:
# plot without title

# %% [markdown]
# ## 2. Development of your own classifier

# %%
my_classifier <- function( love_freq, robberi_freq, motel_freq, prison_freq ){
    
    if (love_freq > 0.005){
        output <- 'romance'
    }
    else if (robberi_freq > 0.0003){
        output <- 'action'
        }
    else if (motel_freq > 0.0003){
        output <- 'action'
    }
    else if (prison_freq > 0.00025){
        output <- 'action'
    }
    else{
        output <- 'romance'
    }
    
    return( output )
    
}

# %%
# test
my_classifier( 0.0001, 0.001, 0.0002, 0.005)
# Out:
# [1] "action"

# %%
# test with a row from training data

#  pick the movie
row_index <- 1 # pick a row number 
movie_title <- training_data[ row_index, 1]
actual_genre <- training_data[ row_index, 2]

#  columns
love_col <- match( 'love', cols)
robberi_col <- match( 'robberi', cols)
motel_col <- match( 'motel', cols)
prison_col <- match( 'prison', cols)

feature_columns <- c(robberi_col, love_col, motel_col, prison_col)

# check column indices
print( feature_columns )

# check frequencies
print( training_data[row_index, feature_columns ] )

# check frequencies
love_freq <- training_data[ row_index, love_col ]
robberi_freq <- training_data[ row_index, robberi_col ]
motel_freq <- training_data[ row_index, motel_col ]
prison_freq <- training_data[ row_index, prison_col ]



# predict
predicted_genre <- my_classifier( love_freq, robberi_freq, motel_freq, prison_freq )

print( paste( 'Movie title: ', movie_title) )
print( paste('Actual genre: ', actual_genre))
print( paste('Predicted genre: ', predicted_genre))
# Out:
# [1] 2450  113 2256  610
#    robberi        love motel prison
# 65       0 0.004836759     0      0
# [1] "Movie title:  my best friend's wedding"
# [1] "Actual genre:  romance"
# [1] "Predicted genre:  romance"

# %%
# write a "predict" function

predict <- function( dataset ){
    
    num_rows <- dim(dataset)[1]
    
    # column indices
    love_col <- match( 'love', cols)
    robberi_col <- match( 'robberi', cols)
    motel_col <- match( 'motel', cols)
    prison_col <- match( 'prison', cols)
    
    # set up a blank dataframe containing one column: predicted genre
    #   and num_training many rows
    output_df <- data.frame( PredictedGenre = double( num_rows ) )
    
    # lop over each row in the training dataset
    row_index <- 1
    while( row_index <= num_rows ){
    
        # frequencies
        love_freq <- dataset[ row_index, love_col ]
        robberi_freq <- dataset[ row_index, robberi_col ]
        motel_freq <- dataset[ row_index, motel_col ]
        prison_freq <- dataset[ row_index, prison_col ]
        
        # predicted genre
        pred <- my_classifier( love_freq, robberi_freq, motel_freq, prison_freq )
        output_df[ row_index, 1 ] <- pred
        row_index <- row_index + 1
    }
    
    return( output_df )
}

# %%
# predict genres of movies in test data

prediction_df <- predict( test_data ) 

head(prediction_df)
# Out:
#   PredictedGenre
# 1 romance
# 2 romance
# 3 action
# 4 romance
# 5 romance
# 6 romance

# %% [markdown]
# ## 3. Assessment of your classifier

# %%
# write a function that computes the accuracy, given two lists

compute_accuracy <- function( actual_genres, predicted_genres ){
    
    num_data <- length(actual_genres)
    num_correct <- sum( actual_genres == predicted_genres)
    accuracy <- num_correct / num_data
    
    return(accuracy)
}

# %%
prediction_accuracy <- compute_accuracy( test_data[,2], prediction_df[,1] )

print( prediction_accuracy )
# Out:
# [1] 0.5753425

# %%
# write another function/metric that assesses the classifier

# for example:
# find the rate of correct predictions out of all romance movies
# (this is essentially the "true positive rate" if our question has been "is this a romance movie?")

compute_true_romance_rate <- function( actual_genres, predicted_genres ){
    num_rows <- length(actual_genres)
    num_romance <- sum( actual_genres == 'romance' )
    
    # loop to count the number of movies that are actually romance and was predicted to be romance
    # counters to be incremented in the loop:
    num_true_romance <- 0
    row_index <- 1
    
    while( row_index <= num_rows ){
        if ( actual_genres[row_index] == predicted_genres[row_index] && actual_genres[row_index] == 'romance' ){
            num_true_romance <- num_true_romance + 1
        }
        row_index <- row_index + 1        
    }
    
    true_romance_rate <- num_true_romance / num_romance
    
    return( true_romance_rate )
}

# %%
prediction_true_romance_rate <- compute_true_romance_rate( test_data[,2], prediction_df[,1] )

print( prediction_true_romance_rate )
# Out:
# [1] 1

# %% [markdown]
# ## 4. k-Nearest Neighbor Classifier

# %%
# we'll do this twice:
# 1. using knn() function from the class library
# 2. using our own knn function, possibly with tweaks
# and compare the results


# -----
# 1. Using knn() from the class library

# first load the class
# if using the class library for the first time, install first
#install.packages('class', repos='http://cran.us.r-project.org')
library(class)
# Out:
# Warning message:
# "package 'class' was built under R version 3.5.3"

# %%
# for starters, try kNN with k = 5
feature_columns <- c(robberi_col, love_col, motel_col, prison_col)
label_column <- 2

# use knn() from class library to predict the genres of movies in test_data 
knn_prediction <- knn( training_data[ , feature_columns], 
                       test_data[ , feature_columns], 
                       cl = training_data[ , label_column], 
                       k = 5 )

# compute the accuracy
knn_prediction_accuracy <- compute_accuracy( test_data[,label_column], knn_prediction )
print(knn_prediction_accuracy )

# compute the "true romance rate"
knn_prediction_true_romance_rate <- compute_true_romance_rate( test_data[,label_column], knn_prediction )
print( knn_prediction_true_romance_rate )
# Out:
# [1] 0.739726
# [1] 0.6060606

# %%
# -----
# 2. Writing our own knn function

# first write a function that computes the distance between two rows
compute_distance <- function( row1, row2 ){
    output <- sqrt( sum( (row1 - row2) ** 2 ) )
    
    return( output )
}

# write a knn function that predicts the label of a new point (row) based on its distance to rows in the training data frame
knn_one_point <- function( training, new_point_row, label_column, feature_columns, k ){
    num_training <- dim( training )[1]
    
    # compute the distance between the new data point and each row in the training data frame
    distances <- data.frame( Distance = double( num_training ) )
    row <- 1
    while (row <= num_training){
        distances[ row, 1 ] <- compute_distance( training[row, feature_columns ], new_point_row[ feature_columns ] )
        row <- row + 1
    }
    
    # find the k closest neighbors and their labels
    row_indices_of_k_nearest_neighbors <- order( distances[,1] )[1:k] # find indices of smallest k distances
    labels_of_k_nearest_neighbors <- training[ row_indices_of_k_nearest_neighbors, label_column ]
    
    # predict label of new point
    
    #  ( here, some students might experiment with other ways to pick a label;
    #     for example by taking into account the distance from new point to each neighbor; closer neighbors might
    #     carry more "vote", etc. )
    
    num_romance <- sum( labels_of_k_nearest_neighbors == 'romance')
    num_action <- sum( labels_of_k_nearest_neighbors == 'action')
    
    # implement majority vote for choosing label of new point; toss an unbiased coin if there is a tie
    if( num_romance < num_action ){
        new_point_label <- 'action'
    }
    else if ( num_romance > num_action ){
        new_point_label <- 'romance'
    }
    else{ # if there is a tie (possible when k is even)
        new_point_label <- sample( c('romance', 'action'), 1)
    }
    
    return( new_point_label )
}


# write a knn function that predicts the label of each row in a test data frame 
#  based on their distances to rows in the training data frame

my_knn <- function( training, test, label_column, feature_columns, k ){
    num_test <- dim( test )[1]
    
    prediction_df <- data.frame( PredictedLabel = double( num_test ) )
    
    row <- 1
    while( row <= num_test){
        
        prediction_df[row, 1] <- knn_one_point( training, test[row,], label_column, feature_columns, k )
        
        row <- row + 1
    }
    
    return( prediction_df )
}

# %%
feature_columns <- c(robberi_col, love_col, motel_col, prison_col)
label_column <- 2 

# for starters, try with k = 5
k <- 5
my_knn_prediction <- my_knn( training_data, test_data, label_column, feature_columns, k)

# %%
# check accuracy and true romance rate

my_knn_accuracy <- compute_accuracy( test_data[, label_column], my_knn_prediction[,1] )
my_knn_true_romance_rate <- compute_true_romance_rate( test_data[,label_column], my_knn_prediction[,1] )

print( my_knn_accuracy )
print( my_knn_true_romance_rate )
# Out:
# [1] 0.739726
# [1] 0.6060606

# %%
sum(knn_prediction == my_knn_prediction[,1])

# the knn() function and our m_knn() function sometimes gives us the same predictions for most of the movies, but not all
#  (this might be caused by ties: for some movies, it might have ties in closest neighbors with different labels)
# Out:
# [1] 73

# %% [markdown]
# ## 5. Writeup (Summary and Conclusion)

# %% [markdown]
# (Your writeup goes here)
